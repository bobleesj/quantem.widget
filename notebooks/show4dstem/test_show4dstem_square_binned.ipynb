# %% [markdown]
# # Show4DSTEM Widget
#
# Interactive 4D-STEM viewer with virtual detector imaging.

# %%
# %load_ext autoreload
# %autoreload 2
# Enable hot module replacement for live widget updates during development
# %env ANYWIDGET_HMR=1

from quantem.core.io.file_readers import read_emdfile_to_4dstem
from quantem.widget import Show4DSTEM
# Out:
# env: ANYWIDGET_HMR=1

# %%
dataset = read_emdfile_to_4dstem('/Users/macbook/data/ptycho_gold_data_2024.h5')
dataset
# Out:
# Dataset(shape=(48, 48, 192, 192), dtype=float32, name='4D-STEM dataset')
#   sampling: [2.38888889 2.38888889 0.45953145 0.45953145]
#   units: ['A', 'A', 'mrad', 'mrad']
#   signal units: 'arb. units'

# %%
# Pass Dataset4dstem directly - calibration auto-extracted
widget = Show4DSTEM(dataset)
widget
# Out:
# Show4DSTEM(shape=(48, 48, 192, 192), sampling=(2.388888888888889 Å, 0.4595314492617885 mrad), pos=(24, 24))

# %% [markdown]
# ## Binned Data

# %%
# binned_dataset = dataset.bin(bin_factors=(2, 2), axes=(2, 3))
# widget_binned = Show4DSTEM(binned_dataset)
# widget_binned

# %% [markdown]
# ## Raster Animation

# %%
# widget_anim = Show4DSTEM(dataset)
# widget_anim.raster(step=10, interval_ms=100, loop=True)

# %% [markdown]
# ## Advanced
#
# Reference for all `Show4DSTEM` parameters and methods.

# %%
# # Manual calibration (overrides dataset values)
# widget_config = Show4DSTEM(
#     dataset.array,
#     pixel_size=2.39,      # Å (real-space)
#     k_pixel_size=0.46,    # mrad (k-space)
#     center=(96, 96),
#     bf_radius=24,
#     log_scale=True,
# )
# widget_config

# %%
# ROI methods (chainable)
widget_roi = Show4DSTEM(dataset)
widget_roi.roi_annular(inner_radius=15, outer_radius=40)
# widget_roi.roi_point()                    # Single pixel
# widget_roi.roi_circle(radius=20)          # Circle
# widget_roi.roi_square(half_size=15)       # Square (30x30)
# widget_roi.roi_rect(width=20, height=10)  # Rectangle
# Out:
# Show4DSTEM(shape=(48, 48, 192, 192), sampling=(2.388888888888889 Å, 0.4595314492617885 mrad), pos=(24, 24))
